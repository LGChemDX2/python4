# %% [markdown]
# # **Topic 3. 데이터프레임 조건 조회_실습**

# %% [markdown]
# ## **(1) 환경준비**

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd

# %% [markdown]
# * 데이터 준비

# %%
data = pd.read_csv('boston.csv')
data.head()

# %% [markdown]
# |	변수	|	설명	|
# |----|----|
# |	medv	|	타운별 집값(중위수)	|
# |	crim	|	범죄율	|
# |	zn2	|	25,000 평방피트를 초과 거주지역 비율 (범주: 0-하, 1-중, 2-상)	|
# |	indus	|	비소매상업지역 면적 비율	|
# |	chas	|	찰스강변 위치(범주 : 강변1, 아니면 0)	|
# |	nox	|	일산화질소 농도	|
# |	rm	|	주택당 방 수	|
# |	age	|	1940년 이전에 건축된 주택의 비율	|
# |	dis	|	직업센터의 거리	|
# |	rad	|	방사형 고속도로까지의 거리	|
# |	tax	|	재산세율	|
# |	ptratio	|	학생/교사 비율	|
# |	lstat	|	인구 중 하위 계층 비율	|

# %% [markdown]
# ## **(2) 실습1 : 조건문**
#
# * ① 시리즈 조회 : 불러온 데이터프레임에서 medv(집값)을 조회하시오.
# * ② 조건문 작성 : 집값이 30보다 작은가?

# %% [markdown]
# ① 시리즈 조회 : 불러온 데이터프레임에서 medv(집값)을 조회하시오.

# %%
data[      ]

# %% [markdown]
# ② 조건문 작성 : 집값이 30보다 작은가?

# %%
data[     ]   30

# %% [markdown]
# ## **(3) 실습2 : 조건조회**
#
# * ① 집값(medv)이 30보다 작은 타운을 조회하시오.
# * ② 집값(medv)이 30보다 작은 타운 조회시, 칼럼은 medv, crim, tax만 조회하시오.
# * ③ 집값(medv)이 30보다 작고, 범죄율(crim)이 0.01보다 작은 타운을 조회하시오.
# * ④ 집값(medv)이 30 ~ 35 사이의 타운을 조회하시오.(.between)
# * ⑤ 고속도로와의 거리(rad)가 1,3,5인 타운을 조회하시오.(.isin)

# %% [markdown]
# ① 집값(medv)이 30보다 작은 타운을 조회하시오.

# %%
data.l  [data[   ]   30]

# %% [markdown]
# ② 집값(medv)이 30보다 작은 타운 조회시, 칼럼은 medv, crim, tax만 조회하시오.

# %%
data.   [    , [    ]]

# %% [markdown]
# ③ 집값(medv)이 30보다 작고, 범죄율(crim)이 0.01보다 작은 타운을 조회하시오.

# %%
data.   [(    ) & (    )]

# %% [markdown]
# ④ 집값(medv)이 30 ~ 35 사이의 타운을 조회하시오.(.between)

# %%
data.   [data['medv'].b ( , )]

# %% [markdown]
# ⑤ 고속도로와의 거리(rad)가 1,3,5인 타운을 조회하시오.(.isin)

# %%
data.   [data['rad'].i   ([   ])]
